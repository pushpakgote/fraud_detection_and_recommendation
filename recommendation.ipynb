# %%
import pandas as pd

# %%
df=pd.read_csv("cleaned_amazon_products.csv")

# %%
df.head(2)
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
#
#        sub_category                                              image  \
# 0  Air Conditioners  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...      4.2           2255
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.2           2948
#
#    discount_price  actual_price  discount%
# 0         32999.0       58990.0   44.06001
# 1         46490.0       75990.0   38.82090

# %% [markdown]
# ## Removing Duplicates

# %%
numeric_cols=['ratings', 'no_of_ratings', 'discount_price', 'actual_price', 'discount%']

# %%
df.shape
# Out:
# (334961, 10)

# %%
df.drop_duplicates().shape
# Out:
# (334961, 10)

# %%
df.name.drop_duplicates()
# Out:
# 0         Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1         LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2         LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3         LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4         Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#                                 ...
# 334956    BE SAVAGE Pink I Purple You Hoodie Suitable fo...
# 334957                  Adidas Regular Fit Men's Track Tops
# 334958            Redwolf Noice Toit Smort - Hoodie (Black)
# 334959       Redwolf Schrute Farms B&B - Hoodie (Navy Blue)
# 334960    Mothercare Printed Cotton Elastane Girls Infan...
# Name: name, Length: 237350, dtype: object

# %%
df[['name']+numeric_cols].drop_duplicates()
# Out:
#                                                      name  ratings  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...      4.2
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...      4.2
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...      4.2
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...      4.0
# 4       Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...      4.1
# ...                                                   ...      ...
# 334956  BE SAVAGE Pink I Purple You Hoodie Suitable fo...      4.6
# 334957                Adidas Regular Fit Men's Track Tops      3.2
# 334958          Redwolf Noice Toit Smort - Hoodie (Black)      2.0
# 334959     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)      4.0
# 334960  Mothercare Printed Cotton Elastane Girls Infan...      4.6
#
#         no_of_ratings  discount_price  actual_price  discount%
# 0                2255         32999.0       58990.0  44.060010
# ...

# %%
index=df[['name']+numeric_cols].drop_duplicates().index

# %%
df_without_duplicates=df.iloc[index].reset_index(drop=True).copy()

# %%
df_without_duplicates
# Out:
#                                                      name     main_category  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...        appliances
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...        appliances
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...        appliances
# 4       Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...        appliances
# ...                                                   ...               ...
# 267912  BE SAVAGE Pink I Purple You Hoodie Suitable fo...  sports & fitness
# 267913                Adidas Regular Fit Men's Track Tops  sports & fitness
# 267914          Redwolf Noice Toit Smort - Hoodie (Black)  sports & fitness
# 267915     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)  sports & fitness
# 267916  Mothercare Printed Cotton Elastane Girls Infan...  sports & fitness
#
# ...

# %% [markdown]
# ## Clustering and Saving

# %%
import clustering as clst
scaler = clst.load_scaling_model()
kmeans=clst.load_clustering_model()

df_without_duplicates['cluster']=clst.predict_cluster(df_without_duplicates.loc[:,['ratings','discount%']],kmeans,scaler)[0]

# %%
df_without_duplicates.to_csv("cleaned_amazon_products_with_cluster_without_duplicates.csv",index=False)

# %% [markdown]
# ## Recommendation

# %%
import pandas as pd
import numpy as np

numeric_cols=['ratings', 'no_of_ratings', 'discount_price', 'actual_price', 'discount%']
category_cols= ['main_category','sub_category']

df=pd.read_csv("cleaned_amazon_products_with_cluster_without_duplicates.csv",usecols=['name']+category_cols+numeric_cols+['cluster'])

# %%
df
# Out:
#                                                      name     main_category  \
# 0       Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        appliances
# 1       LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...        appliances
# 2       LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...        appliances
# 3       LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...        appliances
# 4       Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...        appliances
# ...                                                   ...               ...
# 267912  BE SAVAGE Pink I Purple You Hoodie Suitable fo...  sports & fitness
# 267913                Adidas Regular Fit Men's Track Tops  sports & fitness
# 267914          Redwolf Noice Toit Smort - Hoodie (Black)  sports & fitness
# 267915     Redwolf Schrute Farms B&B - Hoodie (Navy Blue)  sports & fitness
# 267916  Mothercare Printed Cotton Elastane Girls Infan...  sports & fitness
#
# ...

# %%
#Changing categorical cols to numeric
df.main_category=df.main_category.astype('category').cat.codes

df.sub_category=df.sub_category.astype('category').cat.codes

# %%
#numeric_cols=numeric_cols+['cluster']
numeric_cols=['discount_price']

# %%
from sklearn.preprocessing import StandardScaler
scaler_numeric_cols=StandardScaler()
scaler_numeric_cols.fit(df[numeric_cols])
#scaler_numeric_cols.fit(df[[col for col in numeric_cols if col not in ['no_of_ratings']]])
# Out:
# StandardScaler()

# %%
from sklearn.feature_extraction.text import CountVectorizer

#Get most frequently used 5000 words and remove stop words
cv=CountVectorizer(max_features=5000,stop_words='english')
cv.fit(df.name)
# Out:
# CountVectorizer(max_features=5000, stop_words='english')

# %%
def get_feature_cols(product):
    #Convert names to vector
    vector_product=cv.transform(product.name).toarray()
    
    #Category cols to numeric
    category_cols_to_numeric=product[category_cols].values
    
    #Cluster col
    #cluster_col=product.cluster.values
    
    
    
    #Scale numeric cols
    scaled_product=scaler_numeric_cols.transform(product[numeric_cols])
    
    #combine vectorized name and scaled cols 
    #combined_product=np.c_[vector_product,scaled_product]
    
    combined_product=np.c_[vector_product,category_cols_to_numeric,scaled_product]
    
    return combined_product
    
    #return vector_product

# %%
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity

def recommendation(product,df):
    product=product.reset_index(drop=True).copy()
    
    #if product.iloc[0,1]<3:
    #    product.iloc[0,1]=3
    #product.iloc[0,-1]=3
    
    if product.loc[0,'cluster']<3:
        product.loc[0,'cluster']+=1
    
    product=get_feature_cols(product.iloc[0:1])
    similarity=pd.DataFrame([0.0]*df.shape[0],columns=['similarity_score'])
    
    step=10000
    for i in tqdm(range(0,df.shape[0]//step)):
        database_products=get_feature_cols(df.iloc[i*step:i*step+step])
        similarity.iloc[i*step:i*step+step]=cosine_similarity(product,database_products).T
        
    i+=i
    if i*step<df.shape[0]:
        database_products=get_feature_cols(df.iloc[i*step:])
        similarity.iloc[i*step:]=cosine_similarity(product,database_products).T

    return similarity.sort_values('similarity_score',ascending=False).iloc[1:]

# %%
df[df.ratings==1].iloc[35:50]
# Out:
#                                                    name  main_category  \
# 5681  NURAT® Stainless Steel Hand Mixing - Thanddai ...              1
# 5746  RK Incubators Egg Hatching Incubator | Durable...              1
# 5895  Toomh - 180° Rotating Handheld Steam Iron, Por...              1
# 6082  Filfora 22 Watts and 2800rpm Air Cooler and Ex...              1
# 6144  Wooden Puri Maker, Papad Maker. Paratha Maker ...              1
# 6272  Care N Made® RO/UV Aquaguard TAP for All Aquag...              1
# 6295  Spareplanet Vegetable Box Crisper Tray Basket ...              1
# 6376  UR LITTLE SHOP Air Cooler Natural Grass_Coolin...              1
# 6567  Vacuum Sealing Machine Plastic Bag Pouch Impul...              1
# 6627  Havells REO Utsav 1200mm Ceiling Fan (Elegant ...              1
# 6664  DIVALTH Portable Mini Sealing Machine for Bag ...              1
# 6731  Extreme Karigari Weighing Scale Tarazu Childre...              1
# ...

# %%
df.loc[1964]
# Out:
# name              Lifelong Duos 500 Watt 2 Jar Mixer Grinder wit...
# main_category                                                     1
# sub_category                                                      1
# ratings                                                         1.0
# no_of_ratings                                                     2
# discount_price                                               1599.0
# actual_price                                                 3398.0
# discount%                                                  52.94291
# cluster                                                           1
# Name: 1964, dtype: object

# %%
df.name.iloc[63094],df.iloc[63094]
# Out:
# ("Fuoatieec Men's Sneakers Shoe",
#  name              Fuoatieec Men's Sneakers Shoe
#  main_category                                11
#  sub_category                                 27
#  ratings                                     1.0
#  no_of_ratings                                 1
#  discount_price                            499.0
#  actual_price                              999.0
#  discount%                              50.05005
#  cluster                                       1
#  Name: 63094, dtype: object)

# %%
#index=recommendation(df.iloc[18384:18384+1],df)

similarity_df=recommendation(df.iloc[6144:6144+1],df)
# Out:
# 100%|██████████| 26/26 [00:41<00:00,  1.59s/it]

# %%
df.iloc[6144:6144+1]
# Out:
#                                                    name  main_category  \
# 6144  Wooden Puri Maker, Papad Maker. Paratha Maker ...              1
#
#       sub_category  ratings  no_of_ratings  discount_price  actual_price  \
# 6144             1      1.0              2           699.0        1900.0
#
#       discount%  cluster
# 6144   63.21053        1

# %%
df.iloc[similarity_df.index].head(40)

#pd.concat([df.iloc[similarity_df.index],similarity_df],axis=1).head(40)
# Out:
#                                                     name  main_category  \
# 6596   SHIMON POLPAT WOODEN WORKS Wooden Chakla Roti ...              1
# 4390   Matangi Automatic Electric Multi Maker PRM 5.0...              1
# 3918                     Kepzell 2 in 1 Puri momos Maker              1
# 5180   OVEERA 2 in 1 Ata Maker Automatic Non-Electric...              1
# 2888   Decobuy Heavy Puri Poori Maker Press Machine w...              1
# 5418   Diazola 2 in 1 Ata Maker Automatic Non-Electri...              1
# 1901   Spefez Mini Puri Maker Press Ghughra Momos Mak...              1
# 5711   SANPEXA Yogurt Maker Machine, Stainless Steel ...              1
# 3543   Bornix Aluminum Non-Stick Puri/Papad/Maker Pre...              1
# 6426   DIXXITA Heavy duty 4 Kg Iron Puri Machine/Heav...              1
# 5512   YOUR MART Popcorn Maker Machine,1200W Hot Air ...              1
# 2479                              Aeropress Coffee Maker              1
# ...
